# %%
import numpy as np
import pandas as pd

# %%
tesla = pd.read_csv('TSLA.csv')

# %%
tesla['Date'] = pd.to_datetime(tesla.Date)

# %%
# Боксплоты по годам

# %%
tesla.head(5)
# Out:
#         Date       Open   High        Low      Close  Adj Close    Volume
# 0 2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1 2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2 2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3 2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4 2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %% [markdown]
# Выполнил: Латыпов Альберт
#
# Описание: В данном датасете рассматривается ежедневная стоимость одной акции компанни Тесла на
# open - момент открытия биржи
# close - момент закрытия биржи
# high - максимальная стоимость за день
# low - минимальная стоимость за день
# Adj Close - момент закрытия биржи
# volume - количество проданных акций
#
# в периоде с 2010 до 2020 года

# %% [markdown]
# # Временной ряд изменения стоимости акций компании Тесла на рынке ценных бумаг в периоде с 2010 по 2020 годы:

# %%
fig = tesla.loc[
    :, ['Open','High','Low','Close','Adj Close']
        ].plot(kind='line',figsize=(15,8)).get_figure()
fig.savefig("1.png")

# %% [markdown]
# # Стоимость акций в долларах комп. Тесла по различным показателям на начало кадлого года в периоде с 2010 по 2020 годы

# %%
fig = tesla.loc[
    [0,130,382,632,884,1136,1388,1640,1891,2142,2394], ['Open','High','Low','Close','Adj Close']
        ].plot(kind='line',figsize=(15,8)).get_figure()
fig.savefig("2.png")

# %% [markdown]
# # Попарное сравнение различных признаков:

# %%
sns_plot = sns.pairplot(tesla[tesla.columns], size=2.5)
sns_plot.savefig("3.png")
